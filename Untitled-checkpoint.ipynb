# %%
import pandas as pd

# %%
import pandas as pd
movies = pd.read_csv(r'C:\Users\LNS\Documents\Data\imdb_movies.csv')
movies
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
pd.set_options('display.max.rows',11000)
pd.set_options('display.max.columns',22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.set_options('display.max.rows',11000)
#       2 pd.set_options('display.max.columns',22)
#
# AttributeError: module 'pandas' has no attribute 'set_options'

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10842 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10842 non-null  int64
#  1   imdb_id               10834 non-null  object
#  2   popularity            10842 non-null  float64
#  3   budget                10842 non-null  int64
#  4   revenue               10842 non-null  int64
#  5   original_title        10842 non-null  object
#  6   cast                  10767 non-null  object
#  7   homepage              2931 non-null   object
#  8   director              10800 non-null  object
#  9   tagline               8036 non-null   object
#  10  keywords              9367 non-null   object
#  11  overview              10839 non-null  object
#  12  runtime               10842 non-null  int64
#  13  genres                10842 non-null  object
#  14  production_companies  9826 non-null   object
# ...

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies.drop_duplicates(inplace=True)

# %%
movies.dropna(subset=['genres'],inplace=True)

# %%
movies['profit'] = movies['revenue'] - movies['budget']

# %%
movies_genre=movies[['popularity','budget','revenue','original_title','runtime','genres','release_year','vote_count','vote_average','profit']]
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres  release_year  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller          2015        5562
# 1  Action|Adventure|Science Fiction|Thriller          2015        6185
# 2         Adventure|Science Fiction|Thriller          2015        2480
# 3   Action|Adventure|Science Fiction|Fantasy          2015        5292
# 4                      Action|Crime|Thriller          2015        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# ...

# %%
movies_genre.columns
# Out:
# Index(['popularity', 'budget', 'revenue', 'original_title', 'runtime',
#        'release_year', 'vote_count', 'vote_average', 'profit', 'genre_split'],
#       dtype='object')

# %%
from pandas import Series,DataFrame
movies['genres'].str.split('|').apply(Series,1).stack()
# Out:
# C:\Users\LNS\AppData\Local\Temp\ipykernel_10124\2316559453.py:2: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   movies['genres'].str.split('|').apply(Series,1).stack()
# 0      0             Action
#        1          Adventure
#        2    Science Fiction
#        3           Thriller
# 1      0             Action
#                  ...
# 10863  0            Mystery
#        1             Comedy
# 10864  0             Action
#        1             Comedy
# 10865  0             Horror
# Length: 26955, dtype: object

# %%
split=movies_genre['genres'].str.split('|').apply(Series,1).stack()
split.index = split.index.droplevel(-1)
split.name ='genre_split'
del movies_genre['genres']
movies_genre = movies_genre.join(split)
# Out:
# C:\Users\LNS\AppData\Local\Temp\ipykernel_10124\3376524979.py:1: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   split=movies_genre['genres'].str.split('|').apply(Series,1).stack()

# %%
movies_genre
# Out:
#        popularity     budget     revenue            original_title  runtime  \
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 0       32.985763  150000000  1513528810            Jurassic World      124
# 1       28.419936  150000000   378436354        Mad Max: Fury Road      120
# ...           ...        ...         ...                       ...      ...
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10863    0.065141          0           0       Beregis Avtomobilya       94
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10864    0.064317          0           0    What's Up, Tiger Lily?       80
# 10865    0.035919      19000           0  Manos: The Hands of Fate       74
#
# ...

# %%
genres_count = pd.DataFrame(movies_genre.groupby(['genre_split']).original_title.nunique()).sort_values('original_title',ascending=True)
genres_count
# Out:
#                  original_title
# genre_split
# Western                     163
# TV Movie                    167
# Foreign                     188
# War                         269
# History                     331
# Music                       403
# Documentary                 520
# Animation                   697
# Mystery                     796
# Fantasy                     899
# Science Fiction            1207
# Family                     1211
# Crime                      1337
# Adventure                  1442
# Horror                     1580
# Romance                    1686
# Action                     2339
# Thriller                   2841
# Comedy                     3750
# Drama                      4672

# %%
genres_count['original_title'].plot.pie(title='Movies per genre in %',autopct='%1.1f%%',figsize=(10,10))
# Out:
# <Axes: title={'center': 'Movies per genre in %'}, ylabel='original_title'>

# %%
genres_count['original_title'].plot.barh(title='movies per genre',color='darkblue',figsize=(10,9))
# Out:
# <Axes: title={'center': 'movies per genre'}, ylabel='genre_split'>

# %% [markdown]
# #2.Which genre have a high avg budget and revenue ?

# %%
# Get only the numeric columns and calculate their mean by genre_split
genres_avg = movies_genre.groupby('genre_split')[['budget','revenue']].mean()
genre_avg=genres_avg.sort_values('budget',ascending=True)
genre_avg.plot.barh(title='budget and revenue by genre',figsize=(10,9))
# Out:
# <Axes: title={'center': 'budget and revenue by genre'}, ylabel='genre_split'>

# %% [markdown]
# #2.5 Which genres have the highest avg.profit

# %%
genres_avg_profit = movies_genre.groupby('genre_split')['profit'].mean()
genre_avg_profit=genres_avg_profit.sort_values(ascending=True)
genre_avg_pofit.plot.barh(title='profit per genre',figsize=(10,9))
# Out:
# <Axes: title={'center': 'profit per genre'}, ylabel='genre_split'>

# %% [markdown]
# #3.Which genre has the highest avg popularity ?

# %%
genres_avg_pop = movies_genre.groupby('genre_split')['popularity'].mean()
genre_avg_pop=genres_avg_pop.sort_values(ascending=True)
genre_avg_pop.plot.barh(title='popularity per genre',color='pink',figsize=(10,9))
# Out:
# <Axes: title={'center': 'popularity per genre'}, ylabel='genre_split'>

# %% [markdown]
# #4Which genres have the highest number of movies with the avg vote count >=8 ?

# %%
vote_fifty =movies_genre[(movies_genre['vote_count']>=50)&(movies_genre['vote_average']>=8)]
vote_zero=movies_genre[movies_genre['vote_average']>=8]
vote_fifty
# Out:
#        popularity     budget    revenue    original_title  runtime  \
# 9        6.326804  175000000  853708609        Inside Out       94
# 9        6.326804  175000000  853708609        Inside Out       94
# 9        6.326804  175000000  853708609        Inside Out       94
# 35       3.557846    6000000   35401758              Room      117
# 35       3.557846    6000000   35401758              Room      117
# ...           ...        ...        ...               ...      ...
# 10141    2.610362     806948   32000000            Psycho      109
# 10141    2.610362     806948   32000000            Psycho      109
# 10222    2.377288   22000000  321265768  Schindler's List      195
# 10222    2.377288   22000000  321265768  Schindler's List      195
# 10222    2.377288   22000000  321265768  Schindler's List      195
#
#       release_date  vote_count  vote_average     profit genre_split
# 9           6/9/15        3935           8.0  678708609      Comedy
# ...

# %%
genres_votes = pd.DataFrame(vote_fifty.groupby(['genre_split']).vote_average.nunique()).sort_values('vote_average',ascending=True)
genres_votes
# Out:
#                  vote_average
# genre_split
# Fantasy                     1
# Science Fiction             1
# Animation                   1
# Mystery                     1
# Horror                      1
# Family                      1
# Romance                     2
# Music                       2
# History                     2
# Action                      2
# Comedy                      2
# Adventure                   2
# Thriller                    2
# War                         2
# Crime                       4
# Drama                       5
# Documentary                 5

# %%
genres_votes.plot.barh(title='votes per genre',color='brown',figsize=(10,9))
# Out:
# <Axes: title={'center': 'votes per genre'}, ylabel='genre_split'>

# %% [markdown]
# #Hypoithesis
# 1.What are the best movies according to vote average ,return high profit and revenue

# %%
import pandas as pd
movies = pd.read_csv(r'C:\Users\LNS\Documents\Data\imdb_movies.csv')
movies.drop_duplicates(inplace=True)
movies.dropna(subset=['genres'],inplace=True)
movies['profit'] = movies['revenue'] - movies['budget']
movies_genre=movies[['popularity','budget','revenue','original_title','runtime','genres','release_date','vote_count','vote_average','profit']]
movies_genre.head()
# Out:
#    popularity     budget     revenue                original_title  runtime  \
# 0   32.985763  150000000  1513528810                Jurassic World      124
# 1   28.419936  150000000   378436354            Mad Max: Fury Road      120
# 2   13.112507  110000000   295238201                     Insurgent      119
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens      136
# 4    9.335014  190000000  1506249360                     Furious 7      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average      profit
# 0           6.5  1363528810
# 1           7.1   228436354
# ...

# %%
movies_counted = movies_genre[movies_genre['vote_count'] >= 50]
movies_counted
# Out:
#        popularity     budget     revenue                   original_title  \
# 0       32.985763  150000000  1513528810                   Jurassic World
# 1       28.419936  150000000   378436354               Mad Max: Fury Road
# 2       13.112507  110000000   295238201                        Insurgent
# 3       11.173104  200000000  2068178225     Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                        Furious 7
# ...           ...        ...         ...                              ...
# 10821    0.929393          0           0                   Fahrenheit 451
# 10822    0.670274    7500000    33736689  Who's Afraid of Virginia Woolf?
# 10825    0.509263          0           0                          Blow-Up
# 10827    0.410366    1377800           0                           Batman
# 10833    0.737730          0           0           How to Steal a Million
#
#        runtime                                         genres release_date  \
# ...

# %%
# Select only numeric columns for correlation
numeric_columns = movies_counted.select_dtypes(include=['int64', 'float64'])

# Calculate correlation on numeric columns only
correlation_matrix = numeric_columns.corr(method='spearman')

# Display the correlation matrix
correlation_matrix
# Out:
#               popularity    budget   revenue   runtime  vote_count  \
# popularity      1.000000  0.484952  0.588594  0.230214    0.768888
# budget          0.484952  1.000000  0.714733  0.360001    0.554412
# revenue         0.588594  0.714733  1.000000  0.341469    0.682550
# runtime         0.230214  0.360001  0.341469  1.000000    0.263164
# vote_count      0.768888  0.554412  0.682550  0.263164    1.000000
# vote_average    0.189226 -0.044050  0.112201  0.286082    0.285084
# profit          0.498092  0.334345  0.842278  0.211947    0.583606
#
#               vote_average    profit
# popularity        0.189226  0.498092
# budget           -0.044050  0.334345
# revenue           0.112201  0.842278
# runtime           0.286082  0.211947
# vote_count        0.285084  0.583606
# vote_average      1.000000  0.198580
# profit            0.198580  1.000000

# %%
import seaborn as sns
sns.regplot(x='vote_average',y='revenue',data=movies_counted,line_kws={'color':'red'})
# Out:
# <Axes: xlabel='vote_average', ylabel='revenue'>

# %% [markdown]
# #The best movies according to popularity return profit and revenue

# %%
correlation_matrix
# Out:
#               popularity    budget   revenue   runtime  vote_count  \
# popularity      1.000000  0.484952  0.588594  0.230214    0.768888
# budget          0.484952  1.000000  0.714733  0.360001    0.554412
# revenue         0.588594  0.714733  1.000000  0.341469    0.682550
# runtime         0.230214  0.360001  0.341469  1.000000    0.263164
# vote_count      0.768888  0.554412  0.682550  0.263164    1.000000
# vote_average    0.189226 -0.044050  0.112201  0.286082    0.285084
# profit          0.498092  0.334345  0.842278  0.211947    0.583606
#
#               vote_average    profit
# popularity        0.189226  0.498092
# budget           -0.044050  0.334345
# revenue           0.112201  0.842278
# runtime           0.286082  0.211947
# vote_count        0.285084  0.583606
# vote_average      1.000000  0.198580
# profit            0.198580  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x='popularity',y='revenue',data=movies_counted,line_kws={'color':'red'})
plt.figure(figsize=(10,15))
plt.show()

# %% [markdown]
# #3.Highly budgeted movies return high profit

# %%
sns.regplot(x='budget',y='profit',data=movies_counted,line_kws={'color':'red'})
plt.figure(figsize=(10,15))
plt.show()

# %%
#4Highly budgeted movies have a high popularity

# %%
sns.regplot(x='budget',y='popularity',data=movies_counted,line_kws={'color':'red'})
plt.figure(figsize=(10,15))
plt.show()

# %%
time_genre=pd.DataFrame(movies_genre.groupby(['release_year','genre_split'])['profit'].mean())
time_genre
# Out:
#                                     profit
# release_year genre_split
# 1960         Action           6.363125e+06
#              Adventure        4.310000e+05
#              Comedy           5.258750e+06
#              Crime            0.000000e+00
#              Drama            8.245619e+06
# ...                                    ...
# 2015         Science Fiction  8.332130e+07
#              TV Movie        -1.500000e+05
#              Thriller         3.286911e+07
#              War              5.467731e+07
#              Western          7.285662e+07
#
# [1049 rows x 1 columns]
